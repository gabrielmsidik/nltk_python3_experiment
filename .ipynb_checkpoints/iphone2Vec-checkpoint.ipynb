# %% [markdown]
# # iphone2Vec

# %% [markdown]
# © Yuriy Guts, 2016

# %% [markdown]
# Using the text kindly compiled by Eugene Yuen
#
# #### Note: Converted to run on Python 3 and gensim-3.4.0

# %% [markdown]
# ## Imports

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# **Download NLTK tokenizer models (only the first time)**

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/gabrielmanuelsidik/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gabrielmanuelsidik/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Prepare Corpus

# %% [markdown]
# **Load books from files**

# %%
book_filenames = sorted(glob.glob("data/iphone.txt"))

# %%
print("Found books:")
print(book_filenames)
# Out:
# Found books:
# ['data/iphone.txt']

# %% [markdown]
# **Combine the books into one string**

# %%
corpus_raw = u""
print("corpus_raw", corpus_raw)
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# corpus_raw
# Reading 'data/iphone.txt'...
# Corpus is now 507121 characters long

# %% [markdown]
# **Split the corpus into sentences**

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)
# raw_sentences = raw_sentences[0].split("\n")
print(raw_sentences)
# Out:
# ['Turn on iPhone.', 'Press and hold the side button or Sleep/Wake button (depending on your model) until the Apple logo appears.', 'If iPhone doesnt turn on, you might need to charge and monitor the battery.', 'Turn off iPhone.', 'Normally, you leave iPhone on all of the time, but if you need to turn it off, go to Settings > General > Shut Down.', 'If you were given a SIM card to install, install it before setting up iPhone.', 'Important: A Nano-SIM card is required to use cellular services when connecting to GSM networks and some CDMA networks.', 'An iPhone activated on a CDMA wireless network can also use a Nano-SIM card for connecting to a GSM network, primarily for international roaming.', 'Your iPhone is subject to your wireless service provider�s policies, which might include restrictions on switching service providers and roaming, even after the conclusion of any required minimum service contract.', 'Contact your wireless service provider for more details.', 'Availability of cellular capabilities depends on the wireless network, your iPhone model, and your location.', 'Eject the SIM card tray.', 'Insert a paper clip or the SIM eject tool into the small hole of the SIM card tray on the right side of iPhone, then press firmly to eject and remove the tray.', 'Place the SIM card in the tray the angled corner determines the correct orientation then insert the SIM card tray back into iPhone.', 'Set a SIM PIN.', 'To protect your SIM card from others using it for phone calls or cellular data, you can use a SIM PIN.', 'With a SIM PIN, every time you restart your device or remove the SIM card, your SIM card locks and you see �Locked SIM� in the status bar.', 'To create one, go to Settings > Phone.', 'You can set up iPhone over a Wi-Fi network or over your carriers cellular network (not available in all regions).', 'You can also set up iPhone by connecting it to a computer and using iTunes.', 'Prepare for setup.', 'To make setup as smooth as possible, have the following items available: The name and password (if applicable) of your Wi-Fi network.', "Your Apple ID and password; if you don't have an Apple ID, you can create one during setup Your credit or debit card account information, if you want to add a card to Apple Pay during setup on supported models Your previous iPhone or its backup data, if you're upgrading to a new device Your Android device, if you want to move to iOS from Android.", 'Set up iPhone.', 'Turn on iPhone, then follow the setup assistant.', 'If you have another iPhone, iPad, or iPod touch with iOS 11 or later, you can securely copy many of your settings, preferences, and iCloud Keychain to your new iPhone.', 'Hold your other device near your new iPhone, and wait for automatic setup to begin.', "Note: The Find My iPhone app helps you locate and protect your iPhone if it's lost or stolen.", "The app automatically turns on when you sign in with your Apple ID during iPhone setup; the app includes a feature called Activation Lock, which prevents anyone else from activating and using your iPhone, even if it's completely erased.", '(See Find My iPhone.)', 'Before you sell or give away your device, you should erase and unlock it so that the next owner can activate it.', 'Use iPhone on other cellular networks.', 'Some carriers let you unlock iPhone for use with another carrier.', 'To see if your carrier offers this option, see the Apple Support article.', 'Wireless carrier support and features for iPhone.', 'Contact your carrier for authorization and setup information.', 'You need to connect iPhone to iTunes to complete the process.', 'Additional fees may apply.', 'For more information, see the Apple Support article.', 'How to unlock your iPhone for use with another carrier.', 'Use iPhone for business.', 'If your iPhone is deployed or managed by a company or other organization, see an administrator for setup instructions.', 'For general information, go to the Apple at Work website.', 'The Settings app is accessible fr ...

# %%
#convert into a list of words
#remove unnecessary,, split into words, no hyphens
#list of words

def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
# print(raw_sentence)
# print(sentence_to_wordlist(raw_sentences))

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The song corpus contains {0:,} tokens".format(token_count))
# Out:
# The song corpus contains 88,100 tokens

# %% [markdown]
# ## Train Word2Vec

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300
# Minimum word count threshold.
min_word_count = 1

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
iphone2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
iphone2vec.build_vocab(sentences)
# Out:
# 2018-08-06 20:10:43,126 : INFO : collecting all words and their counts
# 2018-08-06 20:10:43,128 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-08-06 20:10:43,154 : INFO : collected 5139 word types from a corpus of 88100 raw words and 6944 sentences
# 2018-08-06 20:10:43,155 : INFO : Loading a fresh vocabulary
# 2018-08-06 20:10:43,167 : INFO : min_count=1 retains 5139 unique words (100% of original 5139, drops 0)
# 2018-08-06 20:10:43,169 : INFO : min_count=1 leaves 88100 word corpus (100% of original 88100, drops 0)
# 2018-08-06 20:10:43,185 : INFO : deleting the raw counts dictionary of 5139 items
# 2018-08-06 20:10:43,187 : INFO : sample=0.001 downsamples 49 most-common words
# 2018-08-06 20:10:43,188 : INFO : downsampling leaves estimated 66282 word corpus (75.2% of prior 88100)
# 2018-08-06 20:10:43,201 : INFO : estimated required memory for 5139 words and 300 dimensions: 14903100 bytes
# 2018-08-06 20:10:43,204 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(iphone2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 5139

# %% [markdown]
# **Start training, this might take a minute or two...**

# %%
iphone2vec.train(sentences, total_examples=iphone2vec.corpus_count, epochs=10)
# Out:
# 2018-08-06 20:10:43,335 : INFO : training model with 4 workers on 5139 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2018-08-06 20:10:43,617 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-06 20:10:43,620 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-06 20:10:43,630 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-06 20:10:43,686 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-06 20:10:43,687 : INFO : EPOCH - 1 : training on 88100 raw words (66342 effective words) took 0.3s, 200800 effective words/s
# 2018-08-06 20:10:43,971 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-06 20:10:43,982 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-06 20:10:43,985 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-06 20:10:44,048 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-06 20:10:44,048 : INFO : EPOCH - 2 : training on 88100 raw words (66292 effective words) took 0.4s, 188111 effective words/s
# 2018-08-06 20:10:44,332 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-06 20:10:44,335 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-06 20:10:44,352 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-06 20:10:44,407 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-06 20:10:44,407 : INFO : EPOCH - 3 : training on 88100 raw words (66321 effective words) took 0.3s, 190150 effective words/s
# 2018-08-06 20:10:44,724 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-06 20:10:44,740 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-06 20:10:44,742 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-06 20:10:44,786 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-06 20:10:44,787 : INFO : EPOCH - 4 : training on 88100 raw words (66359 effective words) took 0.4s, 179613 effective words/s
# 2018-08-06 20:10:45,059 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-06 20:10:45,074 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-06 20:10:45,089 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-06 20:10:45,133 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-06 20:10:45,133 : INFO : EPOCH - 5 : training on 88100 raw words (66220 effective words) took 0.3s, 197093 effective words/s
# 2018-08-06 20:10:45,441 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-06 20:10:45,458 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-06 20:10:45,466 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-06 20:10:45,540 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-06 20:10:45,541 : INFO : EPOCH - 6 : training on 88100 raw words (66374 effective words) took 0.4s, 166438 effective words/s
# 2018-08-06 20:10:45,865 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-06 20:10:45,866 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-06 20:10:45,878 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-06 20:10:45,960 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-06 20:10:45,961 : INFO : EPOCH - 7 : training on 88100 raw words (66281 effective words) took 0.4s, 162027 effective words/s
# 2018-08-06 20:10:46,280 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-06 20:10:46,283 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-06 20:10:46,297 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-06 20:10:46,368 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-06 20:10:46,369 : INFO : EPOCH - 8 : training on 88100 raw words (66235 effective words) took 0.4s, 166176 effective words/s
# 2018-08-06 20:10:46,650 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-06 20:10:46,675 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-06 20:10:46,683 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-06 20:10:46,747 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-06 20:10:46,748 : INFO : EPOCH - 9 : training on 88100 raw words (66225 effective words) took 0.4s, 179584 effective words/s
# 2018-08-06 20:10:47,064 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-08-06 20:10:47,074 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-08-06 20:10:47,084 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-08-06 20:10:47,155 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-08-06 20:10:47,156 : INFO : EPOCH - 10 : training on 88100 raw words (66226 effective words) took 0.4s, 166589 effective words/s
# 2018-08-06 20:10:47,157 : INFO : training on a 881000 raw words (662875 effective words) took 3.8s, 173516 effective words/s
# (662875, 881000)

# %% [markdown]
# **Save to file, can be useful later**

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
iphone2vec.save(os.path.join("trained", "iphone2vec.w2v"))
# Out:
# 2018-08-06 20:10:47,176 : INFO : saving Word2Vec object under trained/iphone2vec.w2v, separately None
# 2018-08-06 20:10:47,178 : INFO : not storing attribute vectors_norm
# 2018-08-06 20:10:47,180 : INFO : not storing attribute cum_table
# 2018-08-06 20:10:47,347 : INFO : saved trained/iphone2vec.w2v

# %% [markdown]
# ## Explore the trained model.

# %%
iphone2vec = w2v.Word2Vec.load(os.path.join("trained", "iphone2vec.w2v"))
# Out:
# 2018-08-06 20:10:47,358 : INFO : loading Word2Vec object from trained/iphone2vec.w2v
# 2018-08-06 20:10:47,492 : INFO : loading wv recursively from trained/iphone2vec.w2v.wv.* with mmap=None
# 2018-08-06 20:10:47,493 : INFO : setting ignored attribute vectors_norm to None
# 2018-08-06 20:10:47,493 : INFO : loading vocabulary recursively from trained/iphone2vec.w2v.vocabulary.* with mmap=None
# 2018-08-06 20:10:47,494 : INFO : loading trainables recursively from trained/iphone2vec.w2v.trainables.* with mmap=None
# 2018-08-06 20:10:47,495 : INFO : setting ignored attribute cum_table to None
# 2018-08-06 20:10:47,496 : INFO : loaded trained/iphone2vec.w2v

# %% [markdown]
# ### Compress the word vectors into 2D space and plot them

# %%
#my video - how to visualize a dataset easily
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = iphone2vec.wv.vectors

# %% [markdown]
# **Train t-SNE, this could take a minute or two...**

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# **Plot the big picture**

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[iphone2vec.wv.vocab[word].index])
            for word in iphone2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#      word          x          y
# 0    Turn -54.894535  35.434471
# 1      on -55.424068  42.802071
# 2  iPhone   3.055158  64.705811
# 3   Press -65.285942  11.303896
# 4     and  -7.132077  36.983967
# 5    hold -64.680405  10.431411
# 6     the -66.510719  -3.325949
# 7    side -65.933495  12.249949
# 8  button -60.685474  -7.629156
# 9      or -17.405987  16.135151

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %% [markdown]
# **Zoom in to some interesting places**

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, c=None, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %% [markdown]
# **Found the House Mottos!**

# %%
plot_region(x_bounds=(0, 2), y_bounds=(0, 2))

# %% [markdown]
# **Can't find anything particularly interesting anymore :(**

# %%
plot_region(x_bounds=(0, 5), y_bounds=(0, 5))

# %% [markdown]
# ### Explore semantic similarities between book characters

# %% [markdown]
# **Words closest to the given word**

# %%
iphone2vec.wv.most_similar("power")
# Out:
# 2018-08-06 20:13:45,303 : INFO : precomputing L2-norms of word weight vectors
# [('adapter', 0.9442613124847412),
#  ('low', 0.9082095623016357),
#  ('Lightning', 0.9047011137008667),
#  ('charger', 0.9046587944030762),
#  ('source', 0.9040544033050537),
#  ('operating', 0.8903533816337585),
#  ('USB', 0.8798372745513916),
#  ('port', 0.8774909973144531),
#  ('applicable', 0.8641255497932434),
#  ('compatible', 0.8635568618774414)]

# %%
iphone2vec.wv.most_similar("Internet")
# Out:
# [('connection', 0.9514724612236023),
#  ('disconnect', 0.9136286973953247),
#  ('connect', 0.9130516052246094),
#  ('cellular', 0.9110375642776489),
#  ('connects', 0.8975969552993774),
#  ('connecting', 0.8967097997665405),
#  ('over', 0.8927992582321167),
#  ('connected', 0.8921526074409485),
#  ('VPN', 0.8919898867607117),
#  ('network', 0.8910934329032898)]

# %%
iphone2vec.wv.most_similar("music")
# Out:
# [('songs', 0.8752909898757935),
#  ('listen', 0.8232103586196899),
#  ('library', 0.8129099011421204),
#  ('podcasts', 0.7807492017745972),
#  ('movies', 0.7781180143356323),
#  ('play', 0.772488534450531),
#  ('playlists', 0.7717540264129639),
#  ('rent', 0.7622779607772827),
#  ('artists', 0.7619733214378357),
#  ('enjoy', 0.7611609697341919)]

# %% [markdown]
# **Linear relationships between word pairs**

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = iphone2vec.wv.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("screen", "brightness", "loud")
# Out:
# screen is related to brightness, as appearing is related to loud
# 'appearing'

# %% [markdown]
# # Time to use this data and model to create the bins

# %% [markdown]
# 	iterating through each word:
# 		bin them into similar clusters (threshold of similarity can be set [see: cosine distance against the average word] via a greedy algorithm or k-means clustering)
# 		{Note: greedy would be O(n^2) complexity, where n is the number of words in the total text}
# 		Keep tally as well of the categories each sentence has words falling into. (Still O(N^2))
#
# 	Resulting output include:
#         1. 2-D array of sentences - categories
#         2. 2-D array of categories - words
#         3. 2-D array of categories - sentences
#     1. All these can be made in O(n) if greedy is used.

# %%
iphone2vec.wv.similarity("listen", "play")
# Out:
# 0.8395646199849931

# %%
iphone2vec.wv.similarity("listen", "network")
# Out:
# 0.4914909168774163

# %%
iphone2vec.wv.similarity("listen", "library")
# Out:
# 0.8528489185484316

# %%
iphone2vec.wv.similarity("listen", "songs")
# Out:
# 0.8904187339834573

# %%
iphone2vec.wv.similarity("turn", "on")
# Out:
# 0.49490002084952484

# %%
iphone2vec.wv.similarity("on", "iPhone")
# Out:
# 0.3730605091199173

# %%
print(iphone2vec.wv.get_vector("off"))
# Out:
# [ 3.32709044e-01  4.83797528e-02 -6.86745718e-03 -1.20650463e-01
#  -6.79503083e-01 -5.45040131e-01 -1.22338332e-01  2.65888840e-01
#  -9.96278524e-02 -3.62501860e-01 -1.01460442e-01  1.67459443e-01
#  -3.10163021e-01  2.72437811e-01  3.61164629e-01 -2.86645412e-01
#  -1.58060580e-01 -1.61325440e-01  2.40905471e-02 -1.48517355e-01
#  -1.70738861e-01 -5.34782112e-02 -2.49582648e-01 -1.54202908e-01
#  -5.04806116e-02 -1.80704534e-01  3.12374622e-01 -1.37710959e-01
#   1.22064441e-01 -2.14105248e-01  1.75122842e-01  1.54121146e-01
#   8.55445415e-02 -5.19003272e-02 -2.42650360e-01 -1.40828684e-01
#  -4.48429435e-02  8.15993398e-02  1.18849404e-01  4.33958232e-01
#  -1.14751644e-01  9.52613428e-02 -3.34329233e-02  1.88015327e-01
#  -1.59691244e-01 -2.17877030e-01 -2.95551330e-01 -2.36758232e-01
#  -8.29584450e-02 -2.28303745e-01  9.27160233e-02  4.80984822e-02
#   7.74815306e-02 -4.14170064e-02 -4.33732904e-02  3.26445639e-01
#   6.19124956e-02 -2.43576486e-02  1.65872931e-01  9.31183845e-02
#   1.67830691e-01  1.04519531e-01 -1.20385773e-02 -1.58240981e-02
#  -2.96294034e-01  7.50112236e-02 -5.79709820e-02  3.73072743e-01
#  -2.23328441e-01  2.34380692e-01  1.14628278e-01 -1.97650731e-01
#  -1.05524480e-01 -2.30951339e-01  5.78404218e-02 -1.45174479e-02
#  -5.03271865e-03 -9.35011357e-02  2.67715733e-02 -2.12595332e-02
#   1.21093042e-01 -1.61571130e-01  1.77326858e-01  3.08844566e-01
#   1.77145414e-02 -2.22566590e-01  9.23713744e-02  1.76530480e-01
#  -1.76714554e-01  1.31909192e-01  5.53328618e-02  3.17037068e-02
#  -2.25755855e-01  2.82939076e-01 -3.50122690e-01 -5.71832135e-02
#   1.07582979e-01 -6.98885694e-02  1.03707388e-01  1.77290723e-01
#  -6.30163923e-02  4.57487591e-02 -1.33607000e-01 -1.45850539e-01
#   5.49355485e-02 -1.18148737e-02 -2.33998477e-01 -8.82072300e-02
#  -9.82679278e-02 -2.53597468e-01 -4.15231250e-02 -7.08825595e-04
#  -2.39218637e-01  2.09289393e-03 -2.85455912e-01  7.67840445e-02
#   1.50088713e-01 -2.06745297e-01  1.19648032e-01  4.01985273e-02
#   2.83769250e-01 -4.16417234e-02  3.21697176e-01 -9.65113193e-02
#  -1.60527363e-01 -1.07138112e-01 -1.13683075e-01 -5.54069579e-02
#   3.43272164e-02 -3.66898626e-01 -1.30269453e-01 -9.52402726e-02
#  -2.56535619e-01  2.39169240e-01  4.06284481e-02 -1.64664850e-01
#  -2.44509354e-01  1.74451441e-01 -4.38836887e-02 -9.57253948e-02
#   3.73426259e-01 -1.42432064e-01  2.42727503e-01 -1.02964155e-01
#   9.15220380e-02  2.98552096e-01  1.45536736e-01 -2.38820072e-02
#   2.26419419e-03 -1.71755180e-01  2.20853284e-01  6.90656230e-02
#  -1.63277015e-01  4.96335417e-01 -6.43786450e-04  9.16823931e-03
#   3.76255773e-02 -9.64304134e-02  1.67825922e-01 -6.52883127e-02
#  -1.70645230e-02 -2.35847846e-01 -8.99725407e-03  3.50121945e-01
#   2.48031914e-01 -8.99311677e-02  1.10987062e-02  1.25852585e-01
#   6.75485656e-03 -2.23063171e-01 -7.94895589e-02 -3.50874722e-01
#  -2.72491891e-02  1.42681137e-01 -1.96424127e-02  1.74112879e-02
#   2.74609905e-02 -1.40814167e-02 -1.36778563e-01 -2.23386601e-01
#   1.19101197e-01 -1.19193293e-01 -1.55946225e-01 -4.99674454e-02
#  -1.05021752e-01  3.71174693e-01  2.00632378e-01  1.86688155e-02
#   1.71925038e-01 -6.07752651e-02  2.84013659e-01 -3.35942805e-02
#   1.67762637e-01  9.13631096e-02 -8.80321264e-02  5.04915677e-02
#   1.74514562e-01 -2.03350070e-03 -2.34920233e-01  1.19482158e-02
#   2.14186817e-01  9.99006815e-03 -1.20265752e-01  9.84872878e-02
#   2.01674849e-01  1.32858247e-01 -1.18330233e-01  3.03386509e-01
#  -5.34739718e-03  6.27320111e-02 -5.21244034e-02  2.22738847e-01
#  -3.92747581e-01  4.41855788e-02  2.12144107e-01 -4.03685629e-01
#   2.38385603e-01 -9.30489302e-02  1.68260023e-01  4.10964377e-02
#  -3.19042444e-01 -3.90636712e-01 -7.66742751e-02  3.55241299e-02
#   3.25431898e-02 -2.41639391e-01 -4.90518585e-02 -1.47459373e-01
#   1.07545927e-01 -2.15050563e-01  1.82966739e-01 -3.91253829e-01
#   3.73189189e-02  8.54427963e-02  1.40025243e-01 -8.74306858e-02
#   6.54866397e-02 -2.84479737e-01 -1.33293808e-01 -3.13086957e-01
#  -1.08470343e-01 -4.88690846e-02  3.85357216e-02 -2.52493881e-02
#   1.82317868e-01  1.33594632e-01  1.00143544e-01 -3.86512727e-01
#   8.31432939e-02  1.06779762e-01 -2.62598395e-01 -2.90471524e-01
#   2.16324002e-01  1.07724540e-01  2.32427735e-02  1.12622268e-01
#  -3.27884316e-01  2.68231928e-01  4.82809125e-03  1.11515619e-01
#  -3.45350802e-02  4.46043015e-02 -2.77194148e-03  8.17123353e-02
#  -1.68179810e-01 -1.08374171e-01 -2.96312094e-01  1.27642974e-01
#   2.33813096e-02  7.26405680e-02  4.33496147e-01  1.75603285e-01
#  -1.26808450e-01 -4.39568192e-01  9.34627131e-02  8.63634422e-03
#   2.70493716e-01  2.68570669e-02 -1.38156310e-01 -1.72829941e-01
#   4.57636006e-02 -5.34981601e-02  2.31117010e-01  2.60460645e-01
#  -1.57641798e-01  1.01746440e-01 -7.74852931e-02 -4.02110428e-01
#   2.69580781e-01 -1.04419738e-01  2.55330410e-02 -3.07583898e-01
#  -1.46898143e-02  1.02941982e-01  4.60618670e-04  1.54252678e-01
#  -1.39504492e-01 -1.26333043e-01  1.02646552e-01  6.68403227e-03]

# %%
class Category:
    
    def __init__(self, word, threshold = 0.8): 
        self.threshold = threshold
        self.words = set()
        self.words.add(word)
        self.num_of_words = 1
        self.average_vector = iphone2vec.wv.get_vector(word)
        self.average_word = word
        
    def add_word(self, word):
        if (word not in self.words):
            self.words.add(word)

            self.average_vector = (
                iphone2vec.wv.get_vector(word) 
                + self.average_vector * self.num_of_words
            )/(self.num_of_words + 1)

            self.average_word = iphone2vec.wv.similar_by_vector(self.average_vector, topn = 1)[0][0]

            self.num_of_words += 1
    
    def is_similar(self, word):
        return iphone2vec.wv.similarity(self.average_word, word) > self.threshold

# %%
test_category = Category("off")

# %%
test_set = {"one", "two"}

# %%
test_set.add("three")

# %%
test_set.add("one")

# %%
print(test_set)
# Out:
# {'three', 'two', 'one'}

# %%
test_category.add_word("on")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-e14b63642ca0> in <module>()
# ----> 1 test_category.add_word("on")
#
# <ipython-input-61-f78e6dc05892> in add_word(self, word)
#      11     def add_word(self, word):
#      12         if (word not in self.words):
# ---> 13             self.words.append(word)
#      14
#      15             self.average_vector = (
#
# AttributeError: 'set' object has no attribute 'append'

# %%
print(test_category.words)
print(test_category.average_word)
print(test_category.is_similar('off'))
# Out:
# {'off'}
# off
# True

# %%
sentence = sentences[1]
categories = []
for sentence in sentences:
    for word in sentence:

        is_added = False

        for category in categories:
            if (category.is_similar(word)):
                category.add_word(word)
                is_added = True
                break

        if (not is_added):
            categories.append(Category(word,0.6))

# %%
for category in categories:
    print(category.words)
# Out:
# ['Turn', 'Sleep', 'Wake', 'button', 'depending', 'on', 'model', 'until', 'logo', 'appears', 'iPhone', 'doesnt', 'on', 'charge', 'monitor', 'the', 'battery', 'iPhone', 'Normally', 'you', 'leave', 'iPhone', 'on', 'the', 'time', 'but', 'if', 'you', 'need', 'it', 'Shut', 'Down', 'If', 'you', 'were', 'given', 'a', 'SIM', 'card', 'to', 'install', 'install', 'it', 'before', 'setting', 'up', 'iPhone', 'Important', 'A', 'Nano', 'SIM', 'card', 'is', 'required', 'to', 'use', 'cellular', 'services', 'when', 'connecting', 'to', 'GSM', 'networks', 'and', 'some', 'CDMA', 'networks', 'An', 'iPhone', 'activated', 'on', 'a', 'CDMA', 'wireless', 'network', 'can', 'also', 'use', 'a', 'Nano', 'SIM', 'card', 'for', 'connecting', 'to', 'a', 'GSM', 'network', 'primarily', 'for', 'international', 'roaming', 'Your', 'iPhone', 'is', 'subject', 'to', 'your', 'wireless', 'service', 'provider', 's', 'policies', 'which', 'might', 'include', 'restrictions', 'on', 'switching', 'service', 'providers', 'and', 'roaming', 'even', 'after', 'the', 'conclusion', 'any', 'required', 'minimum', 'service', 'contract', 'Contact', 'your', 'wireless', 'service', 'provider', 'for', 'more', 'details', 'Availability', 'cellular', 'capabilities', 'depends', 'on', 'the', 'wireless', 'network', 'your', 'iPhone', 'model', 'and', 'your', 'location', 'Eject', 'the', 'SIM', 'card', 'tray', 'Insert', 'a', 'paper', 'clip', 'or', 'the', 'SIM', 'eject', 'tool', 'into', 'the', 'small', 'hole', 'of', 'the', 'SIM', 'card', 'tray', 'on', 'the', 'right', 'side', 'of', 'iPhone', 'press', 'firmly', 'to', 'eject', 'and', 'remove', 'the', 'tray', 'Place', 'the', 'SIM', 'card', 'in', 'the', 'tray', 'the', 'angled', 'corner', 'determines', 'the', 'correct', 'orientation', 'insert', 'the', 'SIM', 'card', 'tray', 'back', 'into', 'iPhone', 'Set', 'a', 'SIM', 'PIN', 'To', 'protect', 'your', 'SIM', 'card', 'from', 'others', 'using', 'it', 'for', 'phone', 'calls', 'or', 'cellular', 'data', 'you', 'can', 'use', 'a', 'SIM', 'PIN', 'With', 'a', 'SIM', 'PIN', 'every', 'time', 'you', 'restart', 'your', 'device', 'or', 'remove', 'the', 'SIM', 'card', 'your', 'SIM', 'card', 'locks', 'and', 'you', 'see', 'Locked', 'SIM', 'in', 'the', 'status', 'bar', 'To', 'create', 'one', 'go', 'to', 'Phone', 'You', 'can', 'set', 'up', 'iPhone', 'over', 'a', 'Wi', 'Fi', 'network', 'or', 'over', 'your', 'carriers', 'cellular', 'network', 'not', 'available', 'in', 'all', 'regions', 'You', 'can', 'also', 'set', 'up', 'iPhone', 'connecting', 'it', 'to', 'a', 'computer', 'and', 'using', 'iTunes', 'Prepare', 'for', 'setup', 'To', 'make', 'setup', 'smooth', 'possible', 'have', 'the', 'following', 'items', 'available', 'The', 'name', 'and', 'password', 'if', 'applicable', 'of', 'your', 'Wi', 'Fi', 'network', 'Your', 'Apple', 'ID', 'and', 'password', 'if', 'you', 'don', 't', 'have', 'Apple', 'ID', 'you', 'can', 'create', 'one', 'during', 'setup', 'Your', 'credit', 'or', 'debit', 'card', 'account', 'information', 'if', 'you', 'want', 'to', 'add', 'a', 'card', 'to', 'Apple', 'Pay', 'during', 'setup', 'on', 'supported', 'models', 'Your', 'previous', 'iPhone', 'or', 'its', 'backup', 'data', 'if', 'you', 're', 'upgrading', 'to', 'a', 'new', 'device', 'Your', 'Android', 'device', 'if', 'you', 'want', 'to', 'move', 'to', 'iOS', 'from', 'Android', 'up', 'iPhone', 'on', 'iPhone', 'follow', 'the', 'setup', 'assistant', 'If', 'you', 'have', 'another', 'iPhone', 'iPad', 'or', 'iPod', 'touch', 'with', 'iOS', 'or', 'later', 'you', 'can', 'securely', 'copy', 'many', 'your', 'settings', 'preferences', 'and', 'iCloud', 'Keychain', 'to', 'your', 'new', 'iPhone', 'Hold', 'your', 'other', 'device', 'near', 'your', 'new', 'iPhone', 'and', 'wait', 'for', 'automatic', 'setup', 'to', 'begin', 'Note', 'The', 'Find', 'My', 'iPhone', 'app', 'helps', 'you', 'locate', 'and', 'protect', 'your', 'iPhone', 'if', 'it', 'lost', 'or', 'stolen', 'The', 'app', 'automatically', 'turns', 'on', 'when', 'you', 'sign', 'in', 'with', 'your', 'Apple', 'ID', 'during', 'iPhone', ' ...
# ['on', 'side', 'button', 'or', 'the', 'turn', 'to', 'Turn', 'off', 'to', 'turn', 'off', 'go', 'to', 'Settings', 'General', 'then', 'then', 'Settings', 'Set', 'Turn', 'then', 'Use', 'To', 'Use', 'choose', 'tap', 'then', 'tap', 'Search', 'Open', 'down', 'reveal', 'field', 'then', 'choose', 'To', 'Go', 'then', 'Tap', 'then', 'Turn', 'Tap', 'then', 'Adjust', 'Tap', 'button', 'Tap', 'button', 'then', 'tap', 'Control', 'Control', 'Set', 'Go', 'then', 'Set', 'Tap', 'tap', 'button', 'then', 'tap', 'tap', 'then', 'at', 'Go', 'General', 'then', 'Set', 'Set', 'Go', 'General', 'then', 'Set', 'Go', 'General', 'then', 'Go', 'General', 'To', 'General', 'Use', 'Go', 'Set', 'Use', 'choose', 'Use', 'Use', 'Go', 'Set', 'Set', 'Set', 'Go', 'then', 'tap', 'Add', 'Account', 'Add', 'Use', 'then', 'To', 'Use', 'until', 'To', 'To', 'button', 'button', 'Go', 'then', 'Go', 'then', 'tap', 'Up', 'Go', 'then', 'then', 'button', 'then', 'To', 'Up', 'To', 'Open', 'choose', 'then', 'Control', 'Use', 'Set', 'quick', 'Use', 'field', 'Use', 'Set', 'Say', 'something', 'text', 'text', 'New', 'Turn', 'Use', 'tab', 'control', 'Control', 'Control', 'To', 'Control', 'Control', 'then', 'text', 'tab', 'topic', 'To', 'hold', 'key', 'key', 'then', 'choose', 'text', 'text', 'Use', 'Set', 'New', 'Tap', 'To', 'Swipe', 'then', 'button', 'lower', 'left', 'button', 'lower', 'Press', 'button', 'button', 'button', 'To', 'Press', 'button', 'then', 'button', 'To', 'button', 'General', 'Accessibility', 'then', 'Open', 'Press', 'button', 'button', 'Go', 'Swipe', 'at', 'Press', 'button', 'at', 'Open', 'Tap', 'Swipe', 'left', 'tap', 'control', 'down', 'Swipe', 'tap', 'Drag', 'To', 'tap', 'at', 'Zoom', 'then', 'zoom', 'tap', 'zoom', 'tap', 'zoom', 'tap', 'hold', 'then', 'zoom', 'down', 'zoom', 'quick', 'at', 'at', 'text', 'button', 'text', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'at', 'text', 'button', 'button', 'button', 'button', 'text', 'at', 'at', 'button', 'button', 'button', 'button', 'text', 'button', 'text', 'button', 'at', 'button', 'button', 'text', 'text', 'at', 'at', 'Call', 'Call', 'Call', 'button', 'text', 'text', 'key', 'key', 'key', 'key', 'key', 'key', 'key', 'key', 'key', 'button', 'enter', 'text', 'text', 'text', 'point', 'text', 'point', 'text', 'text', 'text', 'text', 'text', 'button', 'text', 'text', 'number', 'number', 'at', 'enter', 'text', 'text', 'key', 'key', 'text', 'enter', 'text', 'text', 'key', 'button', 'text', 'point', 'key', 'text', 'text', 'enter', 'enter', 'key', 'key', 'key', 'key', 'key', 'key', 'key', 'key', 'text', 'text', 'number', 'button', 'text', 'button', 'button', 'button', 'button', 'text', 'button', 'text', 'text', 'button', 'text', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'at', 'at', 'button', 'at', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'button', 'text', 'number', 'enter', 'text', 'Call', 'at', 'song', 'song', 'at', 'button', 'text', 'at', 'button', 'button', 'button', 'button', 'of', 'button', 'of', 'of', 'example', 'button', 'example', 'button', 'button', 'button', 'of', 'of', 'example', 'of', 'of', 'text', 'of', 'button', 'button', 'button', 'of', 'button', 'number', 'example', 'number', 'at', 'of', 'enter', 'text', 'enter', 'example', 'of', 'enter', 'key', 'of', 'at', 'of', 'key', 'of', 'key', 'of', 'key', 'key', 'key', 'key', 'key', 'key', 'number', 'of', 'button', 'at', 'of', 'number', 'button', 'number', 'of', 'enter', 'number', 'Call', 'button', 'number', 'number', 'key', 'button', 'key', 'key', 'number', 'Call', 'number', 'Call', 'button', 'say', 'number', 'at', 'example', 'Call', 'Call', 'number', 'number', 'example', 'say', 'button', 'example', 'button', 'button', 'button', 'button', 'button', 'button', 'text', 'of', 'of', 'text', 'of', 'of', 'button', 'number', 'of', 'button', 'Call', 'text', 'Call', 'number', 'button', 'Call', 'button', 'button', 'button', 'at', 'of', ...
# ['iPhone', 'need']
# ['Press', 'hold', 'the']
# ['and', 'your', 'and', 'are', 'are', 'are', 'are', 'is', 'is', 'are', 'is', 'is', 'is', 'are', 'are', 'are', 'are', 'are', 'are', 'are', 'is', 'are', 'are', 'is', 'is', 'is', 'are', 'are', 'are', 'are', 'is', 'are', 'is', 'are', 'is', 'are', 'are', 'is', 'is', 'is', 'is', 'is', 'are', 'are', 'are', 'are', 'is', 'is', 'are', 'is', 'is', 'is', 'is', 'is', 'is', 'are', 'is', 'is', 'are', 'is', 'are', 'are', 'is', 'is', 'are', 'are', 'are', 'is', 'is', 'are', 'is', 'is', 'are', 'is', 'is', 'are', 'are', 'is', 'are', 'are', 'is', 'is', 'is', 'is', 'The', 's', 'is', 'is', 'is', 's', 'Turn', 'The', 's', 'are', 'is', 's', 'The', 's', 's', 'The', 's', 'is', 'are', 'are', 'are', 's', 's', 'The', 'is', 'The', 's', 's', 'The', 'is', 'is', 's', 's', 's', 's', 's', 's', 's', 'is', 'are', 'are', 'Turn', 'Turn', 'is', 'Turn', 'Turn', 'Turn', 'The', 'is', 'is', 'is', 'The', 'are', 'are', 'The', 's', 'The', 's', 'is', 'Turn', 'is', 'are', 'is', 'The', 'are', 's', 's', 'are', 'The', 'is', 's', 'The', 'is', 'are', 'The', 'The', 's', 'The', 's', 'is', 'is', 'is', 'The', 's', 'is', 'The', 'is', 's', 'is', 's', 'is', 'The', 'is', 'is', 'is', 's', 'Turn', 'are', 'is', 'is', 'The', 'is', 's', 'are', 's', 's', 'Turn', 'is', 'The', 'is', 'The', 'The', 'are', 'is', 's', 'Turn', 'is', 'The', 'is', 'The', 'are', 'is', 'is', 'is', 'The', 'is', 'are', 'Turn', 'is', 's', 's', 's', 'The', 'is', 'are', 's', 's', 'is', 'are', 'The', 'The', 'The', 'Turn', 'Turn', 'is', 'are', 's', 'Turn', 'The', 'is', 'The', 'is', 's', 'is', 'is', 'The', 'The', 'is', 'are', 'are', 'are', 'are', 'The', 'are', 's', 'are', 'are', 's', 's', 's', 'are', 'Turn', 's', 'is', 'is', 'are', 's', 'are', 'Turn', 'Turn', 's', 'is', 'is', 'is', 'is', 'is', 's', 's', 'The', 'is', 'is', 's', 'The', 'is', 'The', 'is', 'is', 'The', 'is', 'The', 'is', 's', 's', 'is', 's', 'are', 's', 's', 'is', 's', 's', 's', 'is', 'is', 'are', 's', 'are', 'are', 'is', 's', 's', 'Turn', 's', 's', 's', 'is', 'are', 'is', 'is', 'are', 's', 'are', 's', 'is', 's', 'is', 'is', 'Turn', 'The', 's', 's', 'is', 'is', 'is', 's', 's', 'The', 'are', 'Turn', 'are', 'Turn', 'Turn', 'is', 'are', 'are', 'are', 'is', 'is', 'are', 'The', 'are', 'The', 'is', 'is', 'The', 'The', 'are', 'Turn', 's', 's', 's', 'Turn', 'The', 'The', 'is', 'is', 'Turn', 'Turn', 's', 'is', 's', 'is', 'The', 's', 's', 's', 'is', 'is', 'is', 's', 's', 'The', 's', 's', 's', 's', 's', 's', 's', 'The', 's', 'is', 'The', 'is', 'Turn', 'Turn', 'Turn', 's', 's', 'Turn', 'The', 'is', 'is', 'is', 'are', 'are', 'is', 's', 'Turn', 'Turn', 'Turn', 'is', 'is', 'is', 'is', 'Turn', 'Turn', 'The', 'The', 'The', 'The', 'is', 'The', 'is', 'is', 'The', 'is', 'is', 'are', 'is', 'is', 'The', 'Turn', 'The', 'The', 'The', 'The', 'is', 'is', 'Turn', 'is', 'Turn', 's', 'is', 'is', 's', 'is', 'is', 's', 'is', 'The', 'is', 's', 's', 's', 's', 'is', 'is', 'are', 'are', 'are', 'is', 'The', 'are', 'is', 's', 's', 's', 's', 's', 'is', 'Turn', 'Turn', 'is', 'are', 's', 's', 'is', 'The', 'is', 's', 'is', 'is', 'is', 'is', 'are', 'is', 'The', 's', 'are', 'are', 'Turn', 'The', 's', 'is', 'is', 'are', 'is', 'are', 'Turn', 'is', 'are', 'is', 'are', 'The', 'is', 's', 's', 'are', 's', 'is', 'is', 'is', 'are', 'The', 's', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 'is', 's', 'is', 's', 'is', 'The', 'are', 's', 'Turn', 'are', 'is', 'are', 'Turn', 'are', 'Turn', 'Turn', 'Turn', 'Turn', 'Turn', 'Turn', 'is', 'Turn', 'Turn', 'Turn', 'The', 'is', 'The', 'is', 'is', 'The', 'is', 'The', 'The', 's', 'is', 'The', 'The', 'is', 'The', 'The', 's', 'Turn', 'is', 's', 'is', 'Turn', 'is', 'Turn', 'Turn', 'Turn', 'is', 'Turn', 'Turn', 's', 'Turn', 'is', 'is', 'are', 'is', 'are', 'The', 'The', 'is', 'Turn', 'is', 'Turn', 'are', 'is', 'are', 'is', 'The', 'The', 'is', 'is', 'The', 'is', 'are', 'The', 'are', 'are', 'is', 'are', 'is', 'is', 'are', 'The', 'is', 'is', 'are', 'Turn', 'is', 's', 'Turn', 'are', 'Turn', 'Turn', 'are', 'Turn', 'is', 'The', 's', 'is', 'is', 'are', 'is', 'is', 'Turn', 'is', 'is', 'Turn', 'is',  ...
# ['Apple']
# ['If', 'you', 'might', 'an', 'For', 'For', 'example', 'example', 'For', 'example', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For', 'For']
# ['all']
# ['of', 'of', 'of', 'of', 'at', 'of', 'of', 'at', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'at', 'at', 'of', 'of', 'of', 'of', 'at', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'at', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of']
# ['by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by', 'by']
# ['as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'such', 'as', 'as', 'such', 'as', 'as', 'such', 'as', 'as', 'such', 'as', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'such', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'such', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'as', 'such', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'as', 'such', 'as', 'as', 'as', 'such', 'such', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'such', 'as', 'such', 'as', 'such', 'as', 'as', 'such', 'as', 'such', 'as', 'as', 'as']
# ['s', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 'What', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 'is', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's', 's']
# ['See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'Use', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See', 'See']
# ['photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos', 'photos']
# ['like', 'like', 'like', 'Say', 'say', 'Say', 'like', 'Say', 'my', 'like', 'Say', 'Siri', 'Siri', 'like', 'like', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'say', 'Siri', 'say', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'say', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'say', 'Siri', 'Siri', 'Siri', 'say', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'say', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri']
# ['Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri', 'Siri']
# ['stories', 'stories', 'stories', 'stories']
# ['example', 'example', 'example', 'example', 'example', 'example', 'example', 'example', 'example', 'example', 'example', 'example']
# ['Say', 'like', 'like', 'my', 'Say', 'like', 'my', 'Say', 'like', 'my', 'my', 'like', 'like', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'like', 'like', 'like', 'Say', 'like', 'like', 'Say', 'like', 'Say', 'Say', 'Say', 'Say', 'like', 'Say', 'like', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'like', 'Say', 'like', 'like', 'like', 'like', 'Say', 'like', 'like', 'Say', 'like', 'like', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'like', 'Say', 'like', 'Say', 'like', 'like', 'like', 'like', 'Say', 'like', 'like', 'Say', 'like', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'like', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'like', 'like', 'Say', 'like', 'Say', 'like', 'like', 'Say', 'like', 'Say', 'like', 'Say', 'Say', 'like', 'like', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de', 'de']
# ['t', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't', 't']
# ['off', 'off', 'Turn', 'off', 'Turn', 'off', 'off', 'Turn', 'off', 'Turn', 'Turn', 'off', 'off', 'Turn', 'off', 'Turn', 'Turn', 'Turn', 'off', 'off', 'off', 'Turn', 'off', 'off', 'Turn', 'off', 'off', 'off', 'off', 'off', 'Turn', 'Turn', 'off', 'Turn', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off', 'off']
# ['The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The', 'The']
# ['Invitations']
# ['RSVP']
# ['Repairing']
# ['Distraction']
# ['Navigation']
