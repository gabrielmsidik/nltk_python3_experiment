# %% [markdown]
# # Thrones2Vec

# %% [markdown]
# © Yuriy Guts, 2016

# %% [markdown]
# Using only the raw text of [A Song of Ice and Fire](https://en.wikipedia.org/wiki/A_Song_of_Ice_and_Fire), we'll derive and explore the semantic properties of its words.
#
# Converted to run on Python 3 and gensim-3.4.0

# %% [markdown]
# ## Imports

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# **Download NLTK tokenizer models (only the first time)**

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/gabrielmanuelsidik/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gabrielmanuelsidik/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Prepare Corpus

# %% [markdown]
# **Load books from files**

# %%
book_filenames = sorted(glob.glob("data/*.txt"))

# %%
print("Found books:")
print(book_filenames)
# Out:
# Found books:
# ['data/got1.txt', 'data/got2.txt', 'data/got3.txt', 'data/got4.txt', 'data/got5.txt']

# %% [markdown]
# **Combine the books into one string**

# %%
corpus_raw = u""
print("corpus_raw", corpus_raw)
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# corpus_raw
# Reading 'data/got1.txt'...
# Corpus is now 1770659 characters long
#
# Reading 'data/got2.txt'...
# Corpus is now 4071041 characters long
#
# Reading 'data/got3.txt'...
# Corpus is now 6391405 characters long
#
# Reading 'data/got4.txt'...
# Corpus is now 8107945 characters long
#
# Reading 'data/got5.txt'...
# Corpus is now 9719485 characters long

# %% [markdown]
# **Split the corpus into sentences**

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# Heraldic crest by Virginia Norey.
# ['Heraldic', 'crest', 'by', 'Virginia', 'Norey']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 1,818,103 tokens

# %% [markdown]
# ## Train Word2Vec

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(sentences)
# Out:
# 2018-08-02 13:50:25,216 : INFO : collecting all words and their counts
# 2018-08-02 13:50:25,218 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-08-02 13:50:25,257 : INFO : PROGRESS: at sentence #10000, processed 140984 words, keeping 10280 word types
# 2018-08-02 13:50:25,313 : INFO : PROGRESS: at sentence #20000, processed 279730 words, keeping 13558 word types
# 2018-08-02 13:50:25,350 : INFO : PROGRESS: at sentence #30000, processed 420336 words, keeping 16598 word types
# 2018-08-02 13:50:25,385 : INFO : PROGRESS: at sentence #40000, processed 556581 words, keeping 18324 word types
# 2018-08-02 13:50:25,415 : INFO : PROGRESS: at sentence #50000, processed 686247 words, keeping 19714 word types
# 2018-08-02 13:50:25,454 : INFO : PROGRESS: at sentence #60000, processed 828497 words, keeping 21672 word types
# 2018-08-02 13:50:25,494 : INFO : PROGRESS: at sentence #70000, processed 973830 words, keeping 23093 word types
# 2018-08-02 13:50:25,532 : INFO : PROGRESS: at sentence #80000, processed 1114967 words, keeping 24252 word types
# 2018-08-02 13:50:25,570 : INFO : PROGRESS: at sentence #90000, processed 1260481 words, keeping 26007 word types
# 2018-08-02 13:50:25,606 : INFO : PROGRESS: at sentence #100000, processed 1393203 words, keeping 26884 word types
# 2018-08-02 13:50:25,644 : INFO : PROGRESS: at sentence #110000, processed 1532150 words, keeping 27809 word types
# 2018-08-02 13:50:25,681 : INFO : PROGRESS: at sentence #120000, processed 1680961 words, keeping 28486 word types
# 2018-08-02 13:50:25,717 : INFO : collected 29026 word types from a corpus of 1818103 raw words and 128868 sentences
# 2018-08-02 13:50:25,718 : INFO : Loading a fresh vocabulary
# 2018-08-02 13:50:25,865 : INFO : min_count=3 retains 17277 unique words (59% of original 29026, drops 11749)
# 2018-08-02 13:50:25,866 : INFO : min_count=3 leaves 1802699 word corpus (99% of original 1818103, drops 15404)
# 2018-08-02 13:50:25,919 : INFO : deleting the raw counts dictionary of 29026 items
# 2018-08-02 13:50:25,921 : INFO : sample=0.001 downsamples 50 most-common words
# 2018-08-02 13:50:25,922 : INFO : downsampling leaves estimated 1404424 word corpus (77.9% of prior 1802699)
# 2018-08-02 13:50:26,004 : INFO : estimated required memory for 17277 words and 300 dimensions: 50103300 bytes
# 2018-08-02 13:50:26,005 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 17277

# %% [markdown]
# **Start training, this might take a minute or two...**

# %%
thrones2vec.train(sentences, total_examples=thrones2vec.corpus_count, epochs=10)
# Out:
# 2018-08-02 13:50:36,423 : INFO : training model with 4 workers on 17277 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2018-08-02 13:50:37,465 : INFO : EPOCH 1 - PROGRESS: at 9.86% examples, 134967 words/s, in_qsize 8, out_qsize 1
# 2018-08-02 13:50:38,567 : INFO : EPOCH 1 - PROGRESS: at 22.68% examples, 148300 words/s, in_qsize 7, out_qsize 0

# %% [markdown]
# **Save to file, can be useful later**

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.save(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2018-08-02 11:07:53,179 : INFO : saving Word2Vec object under trained/thrones2vec.w2v, separately None
# 2018-08-02 11:07:53,181 : INFO : not storing attribute vectors_norm
# 2018-08-02 11:07:53,183 : INFO : not storing attribute cum_table
# 2018-08-02 11:07:53,618 : INFO : saved trained/thrones2vec.w2v

# %% [markdown]
# ## Explore the trained model.

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2018-08-02 11:10:28,070 : INFO : loading Word2Vec object from trained/thrones2vec.w2v
# 2018-08-02 11:10:28,418 : INFO : loading wv recursively from trained/thrones2vec.w2v.wv.* with mmap=None
# 2018-08-02 11:10:28,419 : INFO : setting ignored attribute vectors_norm to None
# 2018-08-02 11:10:28,420 : INFO : loading vocabulary recursively from trained/thrones2vec.w2v.vocabulary.* with mmap=None
# 2018-08-02 11:10:28,421 : INFO : loading trainables recursively from trained/thrones2vec.w2v.trainables.* with mmap=None
# 2018-08-02 11:10:28,423 : INFO : setting ignored attribute cum_table to None
# 2018-08-02 11:10:28,424 : INFO : loaded trained/thrones2vec.w2v

# %% [markdown]
# ### Compress the word vectors into 2D space and plot them

# %%
#my video - how to visualize a dataset easily
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = thrones2vec.wv.vectors

# %% [markdown]
# **Train t-SNE, this could take a minute or two...**

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# **Plot the big picture**

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[thrones2vec.wv.vocab[word].index])
            for word in thrones2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(10)
# Out:
#         word         x          y
# 0       This -5.508370  -4.107714
# 1    edition  8.119684  23.548195
# 2        the  0.911705  -4.264375
# 3   complete -3.330148   6.568052
# 4         of  1.027891  -3.694194
# 5   original  7.901198  22.611301
# 6  hardcover  8.010731  23.565920
# 7        ONE  2.460784  26.006708
# 8          A  0.341951  -4.461754
# 9         OF  4.385214  27.134220

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %% [markdown]
# **Zoom in to some interesting places**

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, c=None)
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %% [markdown]
# **People related to Kingsguard ended up together**

# %%
plot_region(x_bounds=(-10, -8), y_bounds=(10, 11))

# %% [markdown]
# **Food products are grouped nicely as well. Aerys (The Mad King) being close to "roasted" also looks sadly correct**

# %%
plot_region(x_bounds=(0, 1), y_bounds=(4, 4.5))

# %% [markdown]
# ### Explore semantic similarities between book characters

# %% [markdown]
# **Words closest to the given word**

# %%
thrones2vec.wv.most_similar("Stark")
# Out:
# [('Eddard', 0.6652941703796387),
#  ('Winterfell', 0.4348703622817993),
#  ('Robb', 0.42871853709220886),
#  ('Catelyn', 0.42598187923431396),
#  ('Snowbeard', 0.4214753210544586),
#  ('Jammos', 0.4084720015525818),
#  ('GEREMY', 0.4011567234992981),
#  ('SHIREI', 0.40062516927719116),
#  ('Edrick', 0.3913743197917938),
#  ('ROSLIN', 0.3889201283454895)]

# %%
thrones2vec.wv.most_similar("Aerys")
# Out:
# [('II', 0.5052138566970825),
#  ('Targaryen', 0.4303550124168396),
#  ('Jaehaerys', 0.39102768898010254),
#  ('Mad', 0.3801114559173584),
#  ('King', 0.35818368196487427),
#  ('Defiance', 0.35231783986091614),
#  ('Robert', 0.3500831723213196),
#  ('Sack', 0.33780738711357117),
#  ('LYANNA', 0.33764275908470154),
#  ('Fifth', 0.33678069710731506)]

# %%
thrones2vec.wv.most_similar("direwolf")
# Out:
# [('SHAGGYDOG', 0.45987433195114136),
#  ('WIND', 0.45599594712257385),
#  ('wolf', 0.43392711877822876),
#  ('GHOST', 0.41951683163642883),
#  ('EDDISON', 0.40709826350212097),
#  ('SUMMER', 0.4035227596759796),
#  ('RICKON', 0.39781665802001953),
#  ('Ghost', 0.39730510115623474),
#  ('DOLOROUS', 0.3932470381259918),
#  ('TOLLETT', 0.3880908191204071)]

# %% [markdown]
# **Linear relationships between word pairs**

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = thrones2vec.wv.most_similar_cosmul(
        positive=[end2, start1],re
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("Stark", "Winterfell", "Riverrun")
nearest_similarity_cosmul("Jaime", "sword", "wine")
nearest_similarity_cosmul("Arya", "Nymeria", "dragons")
# Out:
# Stark is related to Winterfell, as Tully is related to Riverrun
# Jaime is related to sword, as cup is related to wine
# Arya is related to Nymeria, as wyrms is related to dragons
# 'wyrms'
